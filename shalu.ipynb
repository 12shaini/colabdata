# %%
import pandas as pd

# %%
df=pd.read_csv("/content/prouni_2005_2019.csv")

# %%
df
# Out:
#         ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 0                      2005                    423
# 1                      2005                    423
# 2                      2005                    423
# 3                      2005                    423
# 4                      2005                    423
# ...                     ...                    ...
# 131358                 2006                   1496
# 131359                 2006                   1496
# 131360                 2006                   1742
# 131361                 2006                   1742
# 131362                 2006                   1742
#
#                                            NOME_IES_BOLSA         TIPO_BOLSA  \
# 0       UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 1       UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 2       UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# ...

# %%
df1=pd.read_csv("/content/cardata.csv")

# %%
df1
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df2=pd.read_csv("/content/Melbourne_housing_FULL.csv")

# %%
df2
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
df3=pd.read_csv("/content/baseball.csv")

# %%
df3
# Out:
#      Team League  Year   RS   RA    W    OBP    SLG     BA  Playoffs  \
# 0     ARI     NL  2012  734  688   81  0.328  0.418  0.259         0
# 1     ATL     NL  2012  700  600   94  0.320  0.389  0.247         1
# 2     BAL     AL  2012  712  705   93  0.311  0.417  0.247         1
# 3     BOS     AL  2012  734  806   69  0.315  0.415  0.260         0
# 4     CHC     NL  2012  613  759   61  0.302  0.378  0.240         0
# ...   ...    ...   ...  ...  ...  ...    ...    ...    ...       ...
# 1227  PHI     NL  1962  705  759   81  0.330  0.390  0.260         0
# 1228  PIT     NL  1962  706  626   93  0.321  0.394  0.268         0
# 1229  SFG     NL  1962  878  690  103  0.341  0.441  0.278         1
# 1230  STL     NL  1962  774  664   84  0.335  0.394  0.271         0
# 1231  WSA     AL  1962  599  716   60  0.308  0.373  0.250         0
#
#       RankSeason  RankPlayoffs    G   OOBP   OSLG
# 0            NaN           NaN  162  0.317  0.415
# ...

# %%
df4=pd.read_csv("/content/mobile_accelerometer_car_12K.csv")

# %%
df4
# Out:
#            acc_x     acc_y     acc_z  target
# 0      -0.113725  0.083797  9.654618       0
# 1      -0.098162  0.087388  9.630676       0
# 2      -0.099359  0.094571  9.645041       0
# 3      -0.099359  0.089783  9.649830       0
# 4      -0.118513  0.087388  9.634268       0
# ...          ...       ...       ...     ...
# 119995 -0.624887  7.577648  6.683414       1
# 119996 -0.508768  7.480683  6.556521       1
# 119997 -0.409408  7.443573  6.370971       1
# 119998 -0.373495  7.406463  6.108806       1
# 119999 -0.410606  7.387310  5.826290       1
#
# [120000 rows x 4 columns]

# %%
df4.corr()
# Out:
#            acc_x     acc_y     acc_z    target
# acc_x   1.000000 -0.436309 -0.127354 -0.268594
# acc_y  -0.436309  1.000000 -0.603934  0.789805
# acc_z  -0.127354 -0.603934  1.000000 -0.650075
# target -0.268594  0.789805 -0.650075  1.000000

# %%
df5=pd.read_csv("/content/kaggle_hidden_gems.csv")

# %%
df5
# Out:
#      vol        date                                         link_forum  \
# 0      1  2020-05-12              https://www.kaggle.com/general/150603
# 1      1  2020-05-12              https://www.kaggle.com/general/150603
# 2      1  2020-05-12              https://www.kaggle.com/general/150603
# 3      2  2020-05-19              https://www.kaggle.com/general/152383
# 4      2  2020-05-19              https://www.kaggle.com/general/152383
# ..   ...         ...                                                ...
# 295   99  2022-03-29  https://www.kaggle.com/discussions/general/315740
# 296   99  2022-03-29  https://www.kaggle.com/discussions/general/315740
# 297  100  2022-04-05  https://www.kaggle.com/discussions/general/317093
# 298  100  2022-04-05  https://www.kaggle.com/discussions/general/317093
# 299  100  2022-04-05  https://www.kaggle.com/discussions/general/317093
#
#                                           link_twitter  \
# ...

# %%
df6=pd.read_csv("/content/netflix_titles.csv")

# %%
df6
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df7=pd.read_csv("/content/data.csv")

# %%
df7
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# ...

# %%
df8=pd.read_csv("/content/Sales.csv")

# %%
df8
# Out:
#               Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0       2013-11-26   26  November  2013          19.0           Youth (<25)
# 1       2015-11-26   26  November  2015          19.0           Youth (<25)
# 2       2014-03-23   23     March  2014          49.0        Adults (35-64)
# 3       2016-03-23   23     March  2016          49.0        Adults (35-64)
# 4       2014-05-15   15       May  2014          47.0        Adults (35-64)
# ...            ...  ...       ...   ...           ...                   ...
# 108948  2013-11-23   23  November  2013          25.0  Young Adults (25-34)
# 108949  2015-11-23   23  November  2015          25.0  Young Adults (25-34)
# 108950  2014-03-13   13     March  2014          25.0  Young Adults (25-34)
# 108951  2016-03-13   13     March  2016          25.0  Young Adults (25-34)
# 108952  2014-05-09    9       May     2           NaN                   NaN
#
# ...

# %%
df9=pd.read_csv("/content/Bakery sales.csv")

# %%
df9
# Out:
#         Unnamed: 0        date   time  ticket_number               article  \
# 0                0  2021-01-02  08:38       150040.0              BAGUETTE
# 1                1  2021-01-02  08:38       150040.0      PAIN AU CHOCOLAT
# 2                4  2021-01-02  09:14       150041.0      PAIN AU CHOCOLAT
# 3                5  2021-01-02  09:14       150041.0                  PAIN
# 4                8  2021-01-02  09:25       150042.0  TRADITIONAL BAGUETTE
# ...            ...         ...    ...            ...                   ...
# 234000      511387  2022-09-30  18:52       288911.0                 COUPE
# 234001      511388  2022-09-30  18:52       288911.0            BOULE 200G
# 234002      511389  2022-09-30  18:52       288911.0                 COUPE
# 234003      511392  2022-09-30  18:55       288912.0  TRADITIONAL BAGUETTE
# 234004      511395  2022-09-30  18:56       288913.0  TRADITIONAL BAGUETTE
#
#         Quantity unit_price
# 0            1.0     0,90 €
# ...

# %%
df10=pd.read_csv("/content/Ice Cream Sales - temperatures.csv")

# %%
df10
# Out:
#      Temperature  Ice Cream Profits
# 0             39              13.17
# 1             40              11.88
# 2             41              18.82
# 3             42              18.65
# 4             43              17.02
# ..           ...                ...
# 360           99              85.13
# 361           99              87.08
# 362           99              89.29
# 363          101              81.91
# 364          101              85.02
#
# [365 rows x 2 columns]

# %%
df10.corr()
# Out:
#                    Temperature  Ice Cream Profits
# Temperature           1.000000           0.988446
# Ice Cream Profits     0.988446           1.000000
