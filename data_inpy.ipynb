# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Airbnb_updated (1).csv")

# %%
df
# Out:
#            _id      property_type        room_type  bed_type  minimum_nights  \
# 0     10066928          Apartment  Entire home/apt  Real Bed               1
# 1     10021707          Apartment     Private room  Real Bed              14
# 2     10009999          Apartment  Entire home/apt  Real Bed               2
# 3     10006546              House  Entire home/apt  Real Bed               2
# 4     10059244          Apartment  Entire home/apt  Real Bed               2
# ...        ...                ...              ...       ...             ...
# 5550   9799412  Bed and breakfast     Private room  Real Bed               1
# 5551   9887054          Apartment     Private room  Real Bed               3
# 5552   9895628          Apartment  Entire home/apt  Real Bed               5
# 5553   9981541          Apartment     Private room  Real Bed               1
# 5554   9983221          Apartment  Entire home/apt  Real Bed               3
#
# ...

# %%
df.sort_values(["maximum_nights"],ascending=False).head(20)
# Out:
#            _id       property_type        room_type  bed_type  minimum_nights  \
# 4993   6357527           Apartment  Entire home/apt  Real Bed               2
# 5127    744242           Apartment  Entire home/apt  Real Bed               2
# 211   10911771           Apartment     Private room  Real Bed               1
# 1735  19550563           Apartment  Entire home/apt  Real Bed               1
# 1315  16954444           Apartment  Entire home/apt  Real Bed               5
# 4738   4778098           Apartment  Entire home/apt  Real Bed               2
# 2238  22130088           Apartment     Private room  Real Bed               1
# 5028    685373         Condominium  Entire home/apt  Real Bed               3
# 862   14185067           Apartment  Entire home/apt  Real Bed              32
# 4883   5725151           Apartment  Entire home/apt  Real Bed              28
# 378   12791827         Condominium  Entire home/apt  Real Bed               3
# ...

# %%
df.iloc[200:250,0:5]
# Out:
#           _id       property_type        room_type  bed_type  minimum_nights
# 200  11207193         Condominium  Entire home/apt  Real Bed               7
# 201   1127954           Apartment  Entire home/apt  Real Bed               3
# 202  11305966           Apartment  Entire home/apt  Real Bed               4
# 203  11145180           Apartment     Private room  Real Bed               1
# 204  11264406           Apartment  Entire home/apt  Real Bed              60
# 205  11387183           Apartment     Private room  Real Bed               1
# 206  11413023           Apartment  Entire home/apt  Real Bed               2
# 207  11080033           Apartment     Private room  Real Bed              14
# 208   1112838           Apartment  Entire home/apt  Real Bed               3
# 209  11144250           Apartment  Entire home/apt  Real Bed               1
# 210   1089542           Apartment     Private room  Real Bed               2
# ...

# %%
df.iloc[55:100,2:6]
# Out:
#           room_type  bed_type  minimum_nights  maximum_nights
# 55     Private room  Real Bed               1            1125
# 56     Private room  Real Bed               2              45
# 57     Private room  Real Bed               3               7
# 58  Entire home/apt  Real Bed               2            1125
# 59  Entire home/apt  Real Bed               2            1125
# 60     Private room  Real Bed               1            1125
# 61  Entire home/apt  Real Bed               2            1125
# 62  Entire home/apt  Real Bed               5            1125
# 63     Private room  Real Bed               1            1125
# 64     Private room  Real Bed               1            1125
# 65  Entire home/apt  Real Bed               3            1125
# 66     Private room  Real Bed               1            1125
# 67     Private room  Real Bed              28            1125
# 68     Private room  Real Bed               2            1125
# ...

# %%
df.iloc[[55,67,99,107,1004],:]
# Out:
#            _id property_type        room_type  bed_type  minimum_nights  \
# 55    10639317     Apartment     Private room  Real Bed               1
# 67    10458796   Condominium     Private room  Real Bed              28
# 99    10201975     Apartment  Entire home/apt  Real Bed               4
# 107   10324377         House     Private room  Real Bed               1
# 1004  15453288     Apartment  Entire home/apt  Real Bed               5
#
#       maximum_nights          cancellation_policy  accommodates  bedrooms  \
# 55              1125                     flexible             2         1
# 67              1125  strict_14_with_grace_period             2         1
# 99              1125  strict_14_with_grace_period             4         2
# 107             1125                     moderate             1         1
# 1004              12  strict_14_with_grace_period             2         1
#
#       beds  ...  host_total_listings_count          market    country  \
# ...

# %%
df.iloc[500:800:5]
# Out:
#           _id       property_type        room_type  bed_type  minimum_nights  \
# 500  13146333           Apartment  Entire home/apt  Real Bed               1
# 505  13217170           Townhouse     Private room  Real Bed               1
# 510  13328702         Condominium  Entire home/apt  Real Bed               2
# 515  13829859               House  Entire home/apt  Real Bed               3
# 520  13223739         Condominium  Entire home/apt  Real Bed               2
# 525  13368075           Apartment  Entire home/apt  Real Bed              32
# 530  13905218         Guest suite     Private room  Real Bed              28
# 535  14075164               House  Entire home/apt  Real Bed               5
# 540  13414552           Apartment  Entire home/apt  Real Bed              20
# 545  13814845         Condominium  Entire home/apt  Real Bed               3
# 550  13045223           Apartment     Private room  Real Bed               2
# ...

# %%
df.iloc[55]
# Out:
# _id                               10639317
# property_type                    Apartment
# room_type                     Private room
# bed_type                          Real Bed
# minimum_nights                           1
# maximum_nights                        1125
# cancellation_policy               flexible
# accommodates                             2
# bedrooms                                 1
# beds                                     1
# number_of_reviews                        0
# bathrooms                                1
# price                                  137
# extra_people                             0
# guests_included                          1
# review_scores                            0
# cleaning_fee                             0
# host_response_time           Not Specified
# host_response_rate           Not Specified
# host_is_superhost                       No
# host_has_profile_pic                   Yes
# host_identity_verified                  No
# ...

# %%
df.loc[:,["cancellation_policy","availability_30","country"]]
# Out:
#               cancellation_policy  availability_30        country
# 0                        flexible                0         Canada
# 1                        flexible                0  United States
# 2                        flexible                0         Brazil
# 3                        moderate               28       Portugal
# 4                        moderate                0         Canada
# ...                           ...              ...            ...
# 5550                     flexible               30         Turkey
# 5551                     flexible               18      Hong Kong
# 5552                     flexible                0         Brazil
# 5553  strict_14_with_grace_period               30      Hong Kong
# 5554  strict_14_with_grace_period               26       Portugal
#
# [5555 rows x 3 columns]

# %%
df.loc[[555,786,974],["cancellation_policy","beds","latitude"]]
# Out:
#              cancellation_policy  beds   latitude
# 555  strict_14_with_grace_period     3  41.148390
# 786  strict_14_with_grace_period     3 -22.966447
# 974  strict_14_with_grace_period     4 -22.972538

# %%
df[df.maximum_nights=="Monteral"]
# Out:
# Empty DataFrame
# Columns: [_id, property_type, room_type, bed_type, minimum_nights, maximum_nights, cancellation_policy, accommodates, bedrooms, beds, number_of_reviews, bathrooms, price, extra_people, guests_included, review_scores, cleaning_fee, host_response_time, host_response_rate, host_is_superhost, host_has_profile_pic, host_identity_verified, host_listings_count, host_total_listings_count, market, country, longitude, latitude, is_location_exact, availability_30, availability_60, availability_90, availability_365]
# Index: []
#
# [0 rows x 33 columns]

# %%
df[df.maximum_nights>=200]
# Out:
#            _id      property_type        room_type  bed_type  minimum_nights  \
# 0     10066928          Apartment  Entire home/apt  Real Bed               1
# 1     10021707          Apartment     Private room  Real Bed              14
# 2     10009999          Apartment  Entire home/apt  Real Bed               2
# 4     10059244          Apartment  Entire home/apt  Real Bed               2
# 5      1001265        Condominium  Entire home/apt  Real Bed               3
# ...        ...                ...              ...       ...             ...
# 5550   9799412  Bed and breakfast     Private room  Real Bed               1
# 5551   9887054          Apartment     Private room  Real Bed               3
# 5552   9895628          Apartment  Entire home/apt  Real Bed               5
# 5553   9981541          Apartment     Private room  Real Bed               1
# 5554   9983221          Apartment  Entire home/apt  Real Bed               3
#
# ...

# %%
df[df.room_type=="Private room"]
# Out:
#            _id      property_type     room_type       bed_type  \
# 1     10021707          Apartment  Private room       Real Bed
# 9     10133554  Bed and breakfast  Private room       Real Bed
# 10    10138784          Apartment  Private room       Real Bed
# 12    10084023         Guesthouse  Private room          Futon
# 13    10092679          Apartment  Private room  Pull-out Sofa
# ...        ...                ...           ...            ...
# 5547   9944044  Bed and breakfast  Private room       Real Bed
# 5549   9590866          Apartment  Private room       Real Bed
# 5550   9799412  Bed and breakfast  Private room       Real Bed
# 5551   9887054          Apartment  Private room       Real Bed
# 5553   9981541          Apartment  Private room       Real Bed
#
#       minimum_nights  maximum_nights          cancellation_policy  \
# 1                 14            1125                     flexible
# 9                  1            1125                     moderate
# ...

# %%
df[df.country=="Canada"].count()
# Out:
# _id                          649
# property_type                649
# room_type                    649
# bed_type                     649
# minimum_nights               649
# maximum_nights               649
# cancellation_policy          649
# accommodates                 649
# bedrooms                     649
# beds                         649
# number_of_reviews            649
# bathrooms                    649
# price                        649
# extra_people                 649
# guests_included              649
# review_scores                649
# cleaning_fee                 649
# host_response_time           649
# host_response_rate           649
# host_is_superhost            649
# host_has_profile_pic         649
# host_identity_verified       649
# host_listings_count          649
# host_total_listings_count    649
# market                       649
# country                      649
# longitude                    649
# latitude                     649
# ...
