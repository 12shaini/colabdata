# %%
import vega_datasets

# %%
dir(vega_datasets.data)
# Out:
# ['7zip',
#  'airports',
#  'annual_precip',
#  'anscombe',
#  'barley',
#  'birdstrikes',
#  'budget',
#  'budgets',
#  'burtin',
#  'cars',
#  'climate',
#  'co2_concentration',
#  'countries',
#  'crimea',
#  'disasters',
#  'driving',
#  'earthquakes',
#  'ffox',
#  'flare',
#  'flare_dependencies',
#  'flights_10k',
#  'flights_200k',
#  'flights_20k',
#  'flights_2k',
#  'flights_3m',
#  'flights_5k',
#  'flights_airport',
#  'gapminder',
#  'gapminder_health_income',
#  'gimp',
#  'github',
#  'graticule',
#  'income',
#  'iowa_electricity',
#  'iris',
#  'jobs',
#  'la_riots',
#  'londonBoroughs',
#  'londonCentroids',
#  'londonTubeLines',
#  'lookup_groups',
#  'lookup_people',
#  'miserables',
#  'monarchs',
#  'movies',
#  'normal_2d',
#  'obesity',
#  'ohlc',
#  'points',
#  'population',
#  'population_engineers_hurricanes',
#  'seattle_temps',
#  'seattle_weather',
#  'sf_temps',
#  'sp500',
#  'stocks',
#  'udistrict',
#  'unemployment',
# ...

# %%
import pandas as pd

# %%
df=vega_datasets.data.wheat()

# %%
df
# Out:
#     year  wheat  wages
# 0   1565   41.0   5.00
# 1   1570   45.0   5.05
# 2   1575   42.0   5.08
# 3   1580   49.0   5.12
# 4   1585   41.5   5.15
# 5   1590   47.0   5.25
# 6   1595   64.0   5.54
# 7   1600   27.0   5.61
# 8   1605   33.0   5.69
# 9   1610   32.0   5.78
# 10  1615   33.0   5.94
# 11  1620   35.0   6.01
# 12  1625   33.0   6.12
# 13  1630   45.0   6.22
# 14  1635   33.0   6.30
# 15  1640   39.0   6.37
# 16  1645   53.0   6.45
# 17  1650   42.0   6.50
# 18  1655   40.5   6.60
# 19  1660   46.5   6.75
# 20  1665   32.0   6.80
# 21  1670   37.0   6.90
# 22  1675   43.0   7.00
# 23  1680   35.0   7.30
# 24  1685   27.0   7.60
# 25  1690   40.0   8.00
# 26  1695   50.0   8.50
# 27  1700   30.0   9.00
# 28  1705   32.0  10.00
# 29  1710   44.0  11.00
# 30  1715   33.0  11.75
# 31  1720   29.0  12.50
# 32  1725   39.0  13.00
# 33  1730   26.0  13.30
# 34  1735   32.0  13.60
# 35  1740   27.0  14.00
# 36  1745   27.5  14.50
# 37  1750   31.0  15.00
# 38  1755   35.5  15.70
# ...

# %%
df1=vega_datasets.data.zipcodes()

# %%
df1
# Out:
#       zip_code   latitude   longitude         city state  \
# 0        00501  40.922326  -72.637078   Holtsville    NY
# 1        00544  40.922326  -72.637078   Holtsville    NY
# 2        00601  18.165273  -66.722583     Adjuntas    PR
# 3        00602  18.393103  -67.180953       Aguada    PR
# 4        00603  18.455913  -67.145780    Aguadilla    PR
# ...        ...        ...         ...          ...   ...
# 42044    99926  55.094325 -131.566827   Metlakatla    AK
# 42045    99927  55.517921 -132.003244  Point Baker    AK
# 42046    99928  55.395359 -131.675370    Ward Cove    AK
# 42047    99929  56.449893 -132.364407     Wrangell    AK
# 42048    99950  55.542007 -131.432682    Ketchikan    AK
#
#                        county
# 0                     Suffolk
# 1                     Suffolk
# 2                    Adjuntas
# 3                      Aguada
# 4                   Aguadilla
# ...                       ...
# 42044  Prince Wales Ketchikan
# ...

# %%
df2=vega_datasets.data.github()

# %%
df2
# Out:
#                    time  count
# 0   2015-01-01 01:00:00      2
# 1   2015-01-01 04:00:00      3
# 2   2015-01-01 05:00:00      1
# 3   2015-01-01 08:00:00      1
# 4   2015-01-01 09:00:00      3
# ..                  ...    ...
# 950 2015-05-29 17:00:00      1
# 951 2015-05-29 19:00:00      1
# 952 2015-05-30 00:00:00     10
# 953 2015-05-30 09:00:00      1
# 954 2015-05-30 11:00:00      2
#
# [955 rows x 2 columns]

# %%
df3=vega_datasets.data.windvectors()

# %%
df3
# Out:
#       longitude  latitude  dir  dirCat  speed
# 0         0.125    45.125  228     225   3.12
# 1         0.375    45.125  228     225   3.24
# 2         0.625    45.125  229     225   3.34
# 3         0.875    45.125  229     225   3.44
# 4         1.125    45.125  228     225   3.48
# ...         ...       ...  ...     ...    ...
# 4795     -1.125    59.875  155     150   5.96
# 4796     -0.875    59.875  154     150   6.34
# 4797     -0.625    59.875  153     150   6.71
# 4798     -0.375    59.875  152     150   7.09
# 4799     -0.125    59.875  152     150   7.48
#
# [4800 rows x 5 columns]

# %%
df4=vega_datasets.data.ohlc()

# %%
df4
# Out:
#          date   open   high    low  close   signal        ret
# 0  2009-06-01  28.70  30.05  28.45  30.04    short  -4.893964
# 1  2009-06-02  30.04  30.13  28.30  29.63    short  -0.322581
# 2  2009-06-03  29.62  31.79  29.62  31.02    short   3.686636
# 3  2009-06-04  31.02  31.02  29.92  30.18    short   4.510109
# 4  2009-06-05  29.39  30.81  28.85  29.62    short   6.084243
# 5  2009-06-08  30.84  31.82  26.41  29.77    short   1.253918
# 6  2009-06-09  29.77  29.77  27.79  28.27    short  -5.024311
# 7  2009-06-10  26.90  29.74  26.90  28.46    short  -5.466238
# 8  2009-06-11  27.36  28.11  26.81  28.11    short  -8.374384
# 9  2009-06-12  28.08  28.50  27.73  28.15    short  -5.527638
# 10 2009-06-15  29.70  31.09  29.64  30.81     long   3.492063
# 11 2009-06-16  30.81  32.75  30.07  32.68    short   0.155039
# 12 2009-06-17  31.19  32.77  30.64  31.54    short   5.828221
# 13 2009-06-18  31.54  31.54  29.60  30.03    short   8.176101
# ...

# %%
df5=vega_datasets.data.volcano()

# %%
df5
# Out:
#       width  height  values
# 0        87      61     103
# 1        87      61     104
# 2        87      61     104
# 3        87      61     105
# 4        87      61     105
# ...     ...     ...     ...
# 5302     87      61      99
# 5303     87      61      98
# 5304     87      61      98
# 5305     87      61      97
# 5306     87      61      97
#
# [5307 rows x 3 columns]

# %%
df6=vega_datasets.data.climate()

# %%
df6
# Out:
#                STATION                      STATION_NAME  ELEVATION  LATITUDE  \
# 0    GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 1    GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 2    GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 3    GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 4    GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# ..                 ...                               ...        ...       ...
# 739  GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 740  GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 741  GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 742  GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
# 743  GHCND:USW00003812  ASHEVILLE REGIONAL AIRPORT NC US      645.3  35.43194
#
# ...

# %%
df7=vega_datasets.data.crimea()

# %%
df7
# Out:
#          date  wounds  other  disease
# 0  1854-04-01       0    110      110
# 1  1854-05-01       0     95      105
# 2  1854-06-01       0     40       95
# 3  1854-07-01       0    140      520
# 4  1854-08-01      20    150      800
# 5  1854-09-01     220    230      740
# 6  1854-10-01     305    310      600
# 7  1854-11-01     480    290      820
# 8  1854-12-01     295    310     1100
# 9  1855-01-01     230    460     1440
# 10 1855-02-01     180    520     1270
# 11 1855-03-01     155    350      935
# 12 1855-04-01     195    195      560
# 13 1855-05-01     180    155      550
# 14 1855-06-01     330    130      650
# 15 1855-07-01     260    130      430
# 16 1855-08-01     290    110      490
# 17 1855-09-01     355    100      290
# 18 1855-10-01     135     95      245
# 19 1855-11-01     100    140      325
# 20 1855-12-01      40    120      215
# 21 1856-01-01       0    160      160
# 22 1856-02-01       0    100      100
# 23 1856-03-01       0    125       90

# %%
df8=vega_datasets.data.flare()

# %%
df8
# Out:
#       id                  name  parent     size
# 0      1                 flare     NaN      NaN
# 1      2             analytics     1.0      NaN
# 2      3               cluster     2.0      NaN
# 3      4  AgglomerativeCluster     3.0   3938.0
# 4      5    CommunityStructure     3.0   3812.0
# ..   ...                   ...     ...      ...
# 247  248          OperatorList   211.0   5248.0
# 248  249      OperatorSequence   211.0   4190.0
# 249  250        OperatorSwitch   211.0   2581.0
# 250  251          SortOperator   211.0   2023.0
# 251  252         Visualization   169.0  16540.0
#
# [252 rows x 4 columns]

# %%
import pandas as pd

# %%
df9=pd.read_csv("/content/hotel_booking.csv")

# %%
df9
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 74707    City Hotel            0          0               2015
# 74708    City Hotel            0          0               2016
# 74709    City Hotel            0          0               2016
# 74710    City Hotel            0          1               2016
# 74711    City Hotel            0          2               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
df10=vega_datasets.data.disasters()

# %%
df10
# Out:
#                     Entity  Year   Deaths
# 0    All natural disasters  1900  1267360
# 1    All natural disasters  1901   200018
# 2    All natural disasters  1902    46037
# 3    All natural disasters  1903     6506
# 4    All natural disasters  1905    22758
# ..                     ...   ...      ...
# 798               Wildfire  2013       35
# 799               Wildfire  2014       16
# 800               Wildfire  2015       67
# 801               Wildfire  2016       39
# 802               Wildfire  2017       75
#
# [803 rows x 3 columns]
